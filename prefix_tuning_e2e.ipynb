# %%
# !nvidia-smi
# Out:
# Mon Nov  8 22:22:34 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/sedrickkeh/PrefixTuning.git
# !git clone https://github.com/sedrickkeh/dart.git
# !git clone https://github.com/tuetschek/e2e-metrics.git
# Out:
# Cloning into 'PrefixTuning'...
# remote: Enumerating objects: 576, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 576 (delta 65), reused 38 (delta 22), pack-reused 462
# Receiving objects: 100% (576/576), 20.17 MiB | 20.55 MiB/s, done.
# Resolving deltas: 100% (226/226), done.
# Cloning into 'dart'...
# remote: Enumerating objects: 11674, done.
# remote: Counting objects: 100% (11437/11437), done.
# remote: Compressing objects: 100% (8967/8967), done.
# remote: Total 11674 (delta 2529), reused 11336 (delta 2446), pack-reused 237
# Receiving objects: 100% (11674/11674), 271.07 MiB | 27.19 MiB/s, done.
# Resolving deltas: 100% (2565/2565), done.
# Checking out files: 100% (1525/1525), done.
# Cloning into 'e2e-metrics'...
# remote: Enumerating objects: 909, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# ...

# %%
cd PrefixTuning/transformers
# Out:
# /content/PrefixTuning/transformers

# %%
# !pip install -e .
# !pip install git+https://github.com/PyTorchLightning/pytorch-lightning
# !pip install gitpython
# !pip install rouge_score
# !pip install sacrebleu
# !pip install unidecode
# Out:
# Obtaining file:///content/PrefixTuning/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 3.0 MB 12.3 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 52.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 56.7 MB/s
# ...
#   Running setup.py develop for transformers
# ...
#   Cloning https://github.com/PyTorchLightning/pytorch-lightning to /tmp/pip-req-build-euy72hcz
#   Running command git clone -q https://github.com/PyTorchLightning/pytorch-lightning /tmp/pip-req-build-euy72hcz
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 132 kB 14.6 MB/s
# ...
#      |████████████████████████████████| 829 kB 60.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 32.0 MB/s
# ...

# %%
cd ../gpt2
# Out:
# /content/PrefixTuning/gpt2

# %%
import time 
start = time.time()

# !python train_e2e.py --preseqlen 5 --learning_rate 0.00007 --seed 22 --epoch 5 --notes earlystop
# !python run_language_modeling.py         --output_dir=./save_e2e_models_convcheck         --model_type=gpt2         --model_name_or_path=gpt2-medium         --tokenizer_name=gpt2-medium         --per_device_train_batch_size 10         --per_device_eval_batch_size 10         --save_steps 500000         --num_train_epochs 5         --do_train         --train_data_file=./../data/e2e_data/src1_train.txt         --do_eval         --line_by_line         --save_total_limit 1         --overwrite_output_dir         --task_mode data2text         --eval_data_file=./../data/e2e_data/src1_valid.txt          --tuning_mode prefixtune --logging_dir ./runs/save_e2e_models_convcheck/data2textprefixtune_y_5_act_cat_b=10-e=5_d=0.0_u=no_lr=8e-05_w=0.0_s=22_r=n_m=512_earlystop_o=1_o=1         --train_embs no --optim_prefix yes --preseqlen 5 --prefix_mode activation --format_mode cat --gradient_accumulation_steps 1 --learning_rate 8e-05 --weight_decay 0.0 --seed 22 --disable_tqdm --mid_dim 512 --init_random no --use_dropout no --prefix_dropout 0.0 --objective_mode 1 --evaluate_during_training --eval_steps 5000  --cache_dir gpt2-medium-s3 

end = time.time()
print(f"Time taken: {end-start} seconds")
# Out:
# Streaming output truncated to the last 5000 lines.
#  name : Blue Spice | Type : pub | customer rating : 5 out of 5 | near : Crowne Plaza Hotel <|endoftext|> Blue Spice is a pub near Crowne Plaza Hotel with a customer rating of 5 out of 5.  <|endoftext|>
#
# cat
# True False
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#  name : Blue Spice | Type : pub | customer rating : average | near : Burger King <|endoftext|> Blue Spice is a pub near Burger King with an average customer rating.  <|endoftext|>
#
# cat
# True False
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#  name : Blue Spice | Type : pub | customer rating : average | near : Crowne Plaza Hotel <|endoftext|> Blue Spice is a pub near Crowne Plaza Hotel with an average customer rating.  <|endoftext|>
#
# cat
# True False
# ...

# %% [markdown]
# Note that full results can be found in the path `/content/PrefixTuning/gpt2/save_e2e_models_convcheck/data2textprefixtune_y_5_act_cat_b=10-e=5_d=0.0_u=no_lr=7e-05_w=0.0_s=22_r=n_m=512_earlystop_o=1_o=1_test_beam_eval`
