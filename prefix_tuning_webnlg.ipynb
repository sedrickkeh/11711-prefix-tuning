# %%
# !nvidia-smi
# Out:
# Mon Nov  8 18:51:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !git clone https://github.com/sedrickkeh/PrefixTuning.git
# !git clone https://github.com/sedrickkeh/dart.git
# !git clone https://github.com/tuetschek/e2e-metrics.git
# Out:
# Cloning into 'PrefixTuning'...
# remote: Enumerating objects: 576, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 576 (delta 65), reused 38 (delta 22), pack-reused 462
# Receiving objects: 100% (576/576), 20.17 MiB | 14.57 MiB/s, done.
# Resolving deltas: 100% (226/226), done.
# Cloning into 'dart'...
# remote: Enumerating objects: 11674, done.
# remote: Counting objects: 100% (11437/11437), done.
# remote: Compressing objects: 100% (8967/8967), done.
# remote: Total 11674 (delta 2529), reused 11336 (delta 2446), pack-reused 237
# Receiving objects: 100% (11674/11674), 271.07 MiB | 38.43 MiB/s, done.
# Resolving deltas: 100% (2565/2565), done.
# Checking out files: 100% (1525/1525), done.
# Cloning into 'e2e-metrics'...
# remote: Enumerating objects: 909, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 909 (delta 0), reused 1 (delta 0), pack-reused 906
# Receiving objects: 100% (909/909), 106.78 MiB | 37.96 MiB/s, done.
# Resolving deltas: 100% (492/492), done.

# %%
cd PrefixTuning/transformers
# Out:
# /content/PrefixTuning/transformers

# %%
# !pip install -e .
# !pip install git+https://github.com/PyTorchLightning/pytorch-lightning
# !pip install gitpython
# !pip install rouge_score
# !pip install sacrebleu
# !pip install unidecode
# Out:
# Obtaining file:///content/PrefixTuning/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.2.0) (21.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.2.0) (2019.12.20)
# Collecting tokenizers==0.8.1.rc2
#   Downloading tokenizers-0.8.1rc2-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 5.3 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.2.0) (3.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.2.0) (1.19.5)
# Collecting sentencepiece!=0.1.92
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 57.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.2.0) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.2.0) (4.62.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 61.4 MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.2.0) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.2.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.2.0) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.2.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.2.0) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.2.0) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.2.0) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.2.0) (7.1.2)
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
#   Running setup.py develop for transformers
# Successfully installed sacremoses-0.0.46 sentencepiece-0.1.96 tokenizers-0.8.1rc2 transformers-3.2.0
# Collecting git+https://github.com/PyTorchLightning/pytorch-lightning
#   Cloning https://github.com/PyTorchLightning/pytorch-lightning to /tmp/pip-req-build-mf07ws6m
#   Running command git clone -q https://github.com/PyTorchLightning/pytorch-lightning /tmp/pip-req-build-mf07ws6m
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting PyYAML>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 5.2 MB/s
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.6.0.dev0) (4.62.3)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2021.11.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 72.5 MB/s
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.6.0-py3-none-any.whl (329 kB)
#      |████████████████████████████████| 329 kB 43.6 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.6.0.dev0) (2.6.0)
# Requirement already satisfied: torch>=1.7.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.6.0.dev0) (1.9.0+cu111)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 44.6 MB/s
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.6.0.dev0) (21.0)
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.6.0.dev0) (3.7.4.3)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.6.0.dev0) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0.dev0) (2.23.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 37.8 MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning==1.6.0.dev0) (2.4.7)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (1.41.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (57.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (0.4.6)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (3.17.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (1.8.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (0.12.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (0.37.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0.dev0) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0.dev0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0.dev0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0.dev0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (3.1.1)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.0-py3-none-any.whl (6.1 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 54.5 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0.dev0) (21.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 61.4 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0.dev0) (2.0.7)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 50.6 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.6.0.dev0) (3.6.0)
# Building wheels for collected packages: pytorch-lightning, future
#   Building wheel for pytorch-lightning (PEP 517) ... done
#   Created wheel for pytorch-lightning: filename=pytorch_lightning-1.6.0.dev0-py3-none-any.whl size=1028681 sha256=0ebdc9319cf3d8fd7593c56ce3a245f604baba7c7acb5e7af0a12a7c7d3df52d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j1mpg34o/wheels/18/24/dd/8e13b7dfcda990eb2b099a57bb6d705f6d43fb53ecb4ed07bf
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=082feeaf7c6e7acaaa8b9167879530023312104c1d93719b202971267a7a2da0
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built pytorch-lightning future
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, fsspec, aiohttp, torchmetrics, PyYAML, pyDeprecate, future, pytorch-lightning
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# Successfully installed PyYAML-6.0 aiohttp-3.8.0 aiosignal-1.2.0 async-timeout-4.0.0 asynctest-0.13.0 frozenlist-1.2.0 fsspec-2021.11.0 future-0.18.2 multidict-5.2.0 pyDeprecate-0.3.1 pytorch-lightning-1.6.0.dev0 torchmetrics-0.6.0 yarl-1.7.2
# Collecting gitpython
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 5.3 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from gitpython) (3.7.4.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.1 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.9 gitpython-3.1.24 smmap-5.0.0
# Collecting rouge_score
#   Downloading rouge_score-0.0.4-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from rouge_score) (0.12.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from rouge_score) (3.2.5)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.19.5)
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.0.4
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.5 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0
# Collecting unidecode
#   Downloading Unidecode-1.3.2-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.2 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.2

# %%
cd ../gpt2
# Out:
# /content/PrefixTuning/gpt2

# %%
import time 
start = time.time()

# !python train_e2e.py --mode webnlg --preseqlen 5 --learning_rate 0.00005 --bsz 5 --seed 222 --epoch 5 --notes earlystop

end = time.time()
print(f"Time taken: {end-start} seconds")
# Out:
# Streaming output truncated to the last 5000 lines.
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Ariane_5 : manufacturer : Airbus_Defence_and_Space | Airbus_Defence_and_Space : parentCompany : Airbus_Group <|endoftext|> Ariane 5 is a manufacturer of Airbus Defence and Space which parent company is Airbus Group. <|endoftext|>
#
# ['|', 'Aston_Martin_V8', ':', 'assembly', ':', 'United_Kingdom', '|', 'Aston_Martin_V8', ':', 'relatedMeanOfTransportation', ':', 'Aston_Martin_RHAM/1']
# ('assembly', 'relatedMeanOfTransportation')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Aston_Martin_V8 : assembly : United_Kingdom | Aston_Martin_V8 : relatedMeanOfTransportation : Aston_Martin_RHAM/1 <|endoftext|> The assembly of the Aston Martin V8, which is related to transportation, is in the United Kingdom. <|endoftext|>
#
# ['|', 'Aston_Martin_V8', ':', 'manufacturer', ':', 'Aston_Martin', '|', 'Aston_Martin_V8', ':', 'successor', ':', 'Aston_Martin_Virage']
# ('manufacturer', 'successor')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Aston_Martin_V8 : manufacturer : Aston_Martin | Aston_Martin_V8 : successor : Aston_Martin_Virage <|endoftext|> Aston Martin V8 is a successor to Aston Martin which was manufactured by Aston Martin. <|endoftext|>
#
# ['|', 'Aston_Martin_V8', ':', 'relatedMeanOfTransportation', ':', 'Aston_Martin_DBS', '|', 'Aston_Martin_V8', ':', 'successor', ':', 'Aston_Martin_Virage']
# ('relatedMeanOfTransportation', 'successor')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Aston_Martin_V8 : relatedMeanOfTransportation : Aston_Martin_DBS | Aston_Martin_V8 : successor : Aston_Martin_Virage <|endoftext|> The Aston Martin Virage is the successor to the Aston Martin DBS. <|endoftext|>
#
# ['|', 'Aston_Martin_V8', ':', 'successor', ':', 'Aston_Martin_Virage', '|', 'Aston_Martin_Virage', ':', 'manufacturer', ':', 'Aston_Martin']
# ('successor', 'manufacturer')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Aston_Martin_V8 : successor : Aston_Martin_Virage | Aston_Martin_Virage : manufacturer : Aston_Martin <|endoftext|> Aston Martin Virage is a successor to Aston Martin who are the manufacturer of the Aston Martin V8. <|endoftext|>
#
# ['|', 'Atlas_II', ':', 'finalFlight', ':', '1998-03-16', '|', 'Atlas_II', ':', 'diameter', ':', '3.04', 'm']
# ('finalFlight', 'diameter')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Atlas_II : finalFlight : 1998-03-16 | Atlas_II : diameter : 3.04 m <|endoftext|> The final flight of Atlas II, which has a diameter of 3.04 metres, was on the 16th of March 1998. <|endoftext|>
#
# ['|', 'Atlas_II', ':', 'launchSite', ':', 'Cape_Canaveral_Air_Force_Station', '|', 'Atlas_II', ':', 'manufacturer', ':', 'Lockheed_Martin']
# ('launchSite', 'manufacturer')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Atlas_II : launchSite : Cape_Canaveral_Air_Force_Station | Atlas_II : manufacturer : Lockheed_Martin <|endoftext|> Lockheed Martin is the manufacturer of Atlas II which was launched at the Cape Canaveral Air Force Station. <|endoftext|>
#
# ['|', 'Audi_A1', ':', 'manufacturer', ':', 'Audi', '|', 'Audi', ':', 'division', ':', 'Audi_e-tron']
# ('manufacturer', 'division')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Audi_A1 : manufacturer : Audi | Audi : division : Audi_e-tron <|endoftext|> Audi A1 is a division of Audi which is the manufacturer of Audi e-tron. <|endoftext|>
#
# ['|', 'Audi_A1', ':', 'manufacturer', ':', 'Audi', '|', 'Audi', ':', 'subsidiary', ':', 'Ducati']
# ('manufacturer', 'subsidiary')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Audi_A1 : manufacturer : Audi | Audi : subsidiary : Ducati <|endoftext|> Audi A1 is a subsidiary of Ducati manufacturer Audi. <|endoftext|>
#
# ['|', 'Audi_A1', ':', 'manufacturer', ':', 'Audi', '|', 'Audi', ':', 'subsidiary', ':', 'Quattro_GmbH']
# ('manufacturer', 'subsidiary')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Audi_A1 : manufacturer : Audi | Audi : subsidiary : Quattro_GmbH <|endoftext|> Audi A1 is a subsidiary of Quattro GmbH. <|endoftext|>
#
# ['|', 'Caterpillar_Inc.', ':', 'keyPerson', ':', 'Douglas_R._Oberhelman', '|', 'AIDAluna', ':', 'powerType', ':', 'Caterpillar_Inc.']
# ('keyPerson', 'powerType')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Caterpillar_Inc. : keyPerson : Douglas_R._Oberhelman | AIDAluna : powerType : Caterpillar_Inc. <|endoftext|> Douglas R. Oberhelman is a key person in the Caterpillar Inc. <|endoftext|>
#
# ['|', 'Delta_II', ':', 'launchSite', ':', 'Vandenberg_Air_Force_Base', '|', 'Antares_(rocket)', ':', 'comparable', ':', 'Delta_II']
# ('launchSite', 'comparable')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Delta_II : launchSite : Vandenberg_Air_Force_Base | Antares_(rocket) : comparable : Delta_II <|endoftext|> Antares is a rocket similar to Delta II and was launched from Vandenberg Air Force Base. <|endoftext|>
#
# ['|', 'Finland', ':', 'leaderName', ':', 'Juha_Sipilä', '|', 'Aleksey_Chirikov_(icebreaker)', ':', 'builder', ':', 'Finland']
# ('leaderName', 'builder')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Finland : leaderName : Juha_Sipilä | Aleksey_Chirikov_(icebreaker) : builder : Finland <|endoftext|> Juha Sipilä is the leader of Finland where the icebreaker Aleksey Chirikov was built. <|endoftext|>
#
# ['|', 'General_Dynamics_Electric_Boat', ':', 'parentCompany', ':', 'General_Dynamics', '|', 'American_submarine_NR-1', ':', 'builder', ':', 'General_Dynamics_Electric_Boat']
# ('parentCompany', 'builder')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | General_Dynamics_Electric_Boat : parentCompany : General_Dynamics | American_submarine_NR-1 : builder : General_Dynamics_Electric_Boat <|endoftext|> General Dynamics Electric Boat is the builder of the American submarine NR-1. <|endoftext|>
#
# ['|', 'MTU_Friedrichshafen', ':', 'owner', ':', 'Rolls-Royce_Holdings', '|', 'A-Rosa_Luna', ':', 'powerType', ':', 'MTU_Friedrichshafen']
# ('owner', 'powerType')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | MTU_Friedrichshafen : owner : Rolls-Royce_Holdings | A-Rosa_Luna : powerType : MTU_Friedrichshafen <|endoftext|> The owner of MTU Friedrichshafen is Rolls-Royce Holdings and it is the type of MTU Friedrichshafen. <|endoftext|>
#
# ['|', 'United_Kingdom', ':', 'leaderName', ':', 'Elizabeth_II', '|', 'Aston_Martin_V8', ':', 'assembly', ':', 'United_Kingdom']
# ('leaderName', 'assembly')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | United_Kingdom : leaderName : Elizabeth_II | Aston_Martin_V8 : assembly : United_Kingdom <|endoftext|> Elizabeth II is a leader in the United Kingdom where the Aston Martin V8 is an assembly unit. <|endoftext|>
#
# ['|', 'Aaron_S._Daggett', ':', 'award', ':', 'Purple_Heart', '|', 'Aaron_S._Daggett', ':', 'birthPlace', ':', 'Maine', '|', 'Aaron_S._Daggett', ':', 'battles', ':', 'Battle_of_Fredericksburg']
# ('award', 'birthPlace', 'battles')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Aaron_S._Daggett : award : Purple_Heart | Aaron_S._Daggett : birthPlace : Maine | Aaron_S._Daggett : battles : Battle_of_Fredericksburg <|endoftext|> Aaron S. Daggett was born in Maine and was awarded the Purple Heart. He fought in the Battle of Fredericksburg. <|endoftext|>
#
# ['|', 'Ab_Klink', ':', 'almaMater', ':', 'Erasmus_University_Rotterdam', '|', 'Ab_Klink', ':', 'party', ':', 'Christian_Democratic_Appeal', '|', 'Ab_Klink', ':', 'birthPlace', ':', 'Netherlands']
# ('almaMater', 'party', 'birthPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Ab_Klink : almaMater : Erasmus_University_Rotterdam | Ab_Klink : party : Christian_Democratic_Appeal | Ab_Klink : birthPlace : Netherlands <|endoftext|> Ab Klink was born in the Netherlands and attended Erasmus University Rotterdam. He is a member of the Christian Democratic Appeal party. <|endoftext|>
#
# ['|', "Abdul_Rahman_Ya'kub", ':', 'hasDeputy', ':', 'Stephen_Yong_Kuet_Tze', '|', 'Abdul_Taib_Mahmud', ':', 'birthPlace', ':', 'Kingdom_of_Sarawak', '|', 'Abdul_Taib_Mahmud', ':', 'successor', ':', "Abdul_Rahman_Ya'kub"]
# ('hasDeputy', 'birthPlace', 'successor')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Abdul_Rahman_Ya'kub : hasDeputy : Stephen_Yong_Kuet_Tze | Abdul_Taib_Mahmud : birthPlace : Kingdom_of_Sarawak | Abdul_Taib_Mahmud : successor : Abdul_Rahman_Ya'kub <|endoftext|> Abdul Taib Mahmud was born in the Kingdom of Sarawak and is the successor of Abdul Rahman Ya'kub who was born in the Kingdom of Saudi Arabia. <|endoftext|>
#
# ['|', 'Abdul_Taib_Mahmud', ':', 'residence', ':', 'Sarawak', '|', 'Abdul_Taib_Mahmud', ':', 'birthPlace', ':', 'Kingdom_of_Sarawak', '|', 'Abdul_Taib_Mahmud', ':', 'party', ':', '"Barisan', "Ra'ayat", 'Jati', 'Sarawak"']
# ('residence', 'birthPlace', 'party')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Abdul_Taib_Mahmud : residence : Sarawak | Abdul_Taib_Mahmud : birthPlace : Kingdom_of_Sarawak | Abdul_Taib_Mahmud : party : "Barisan Ra'ayat Jati Sarawak" <|endoftext|> Abdul Taib Mahmud was born in Sarawak and lives in the Kingdom of Sarawak. He is a member of the Barisan Ra'ayat Jati Sarawak. <|endoftext|>
#
# ['|', 'Abdulsalami_Abubakar', ':', 'birthPlace', ':', 'Niger_State', '|', 'Abdulsalami_Abubakar', ':', 'almaMater', ':', 'Technical_Institute,_Kaduna', '|', 'Abdulsalami_Abubakar', ':', 'office', '(workedAt,', 'workedAs)', ':', 'Chief_of_the_Defence_Staff_(Nigeria)']
# ('birthPlace', 'almaMater', 'office (workedAt, workedAs)')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Abdulsalami_Abubakar : birthPlace : Niger_State | Abdulsalami_Abubakar : almaMater : Technical_Institute,_Kaduna | Abdulsalami_Abubakar : office (workedAt, workedAs) : Chief_of_the_Defence_Staff_(Nigeria) <|endoftext|> Abdulsalami Abubakar was born in Niger State and worked as a technician at the Technical Institute Kaduna. He was appointed as the Chief of the Defence Staff in Nigeria. <|endoftext|>
#
# ['|', 'Abdulsalami_Abubakar', ':', 'successor', ':', 'Olusegun_Obasanjo', '|', 'Abdulsalami_Abubakar', ':', 'militaryBranch', ':', 'Nigerian_Air_Force', '|', 'Olusegun_Obasanjo', ':', 'inOfficeWhileVicePresident', ':', 'Atiku_Abubakar']
# ('successor', 'militaryBranch', 'inOfficeWhileVicePresident')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Abdulsalami_Abubakar : successor : Olusegun_Obasanjo | Abdulsalami_Abubakar : militaryBranch : Nigerian_Air_Force | Olusegun_Obasanjo : inOfficeWhileVicePresident : Atiku_Abubakar <|endoftext|> Olusegun Obasanjo is the successor to Atiku Obasanjo in the Nigerian Air Force. He is the Vice President of Abdulsalami Abubakar. <|endoftext|>
#
# ['|', 'Abdulsalami_Abubakar', ':', 'successor', ':', 'Olusegun_Obasanjo', '|', 'Abdulsalami_Abubakar', ':', 'militaryBranch', ':', 'Nigerian_Army', '|', 'Olusegun_Obasanjo', ':', 'inOfficeWhileVicePresident', ':', 'Atiku_Abubakar']
# ('successor', 'militaryBranch', 'inOfficeWhileVicePresident')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Abdulsalami_Abubakar : successor : Olusegun_Obasanjo | Abdulsalami_Abubakar : militaryBranch : Nigerian_Army | Olusegun_Obasanjo : inOfficeWhileVicePresident : Atiku_Abubakar <|endoftext|> Olusegun Obasanjo is the successor of Atiku Abubakar, the Vice President of Abdulsalami Abubakar. The Nigerian Army is a branch of the Nigerian Army. <|endoftext|>
#
# ['|', 'Abel_Caballero', ':', 'birthPlace', ':', 'Ponteareas', '|', 'Abel_Caballero', ':', 'office', '(workedAt,', 'workedAs)', ':', '"Member', 'of', 'the', 'Congress', 'of', 'Deputies"', '|', 'Abel_Caballero', ':', 'birthPlace', ':', 'Galicia_(Spain)']
# ('birthPlace', 'office (workedAt, workedAs)', 'birthPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Abel_Caballero : birthPlace : Ponteareas | Abel_Caballero : office (workedAt, workedAs) : "Member of the Congress of Deputies" | Abel_Caballero : birthPlace : Galicia_(Spain) <|endoftext|> Abel Caballero was born in Ponteareas and worked as a member of the Congress of Deputies in Galicia, Spain. <|endoftext|>
#
# ['|', 'Abel_Caballero', ':', 'birthPlace', ':', 'Spain', '|', 'Abel_Caballero', ':', 'birthPlace', ':', 'Galicia_(Spain)', '|', 'Abel_Caballero', ':', 'party', ':', "Spanish_Socialist_Workers'_Party"]
# ('birthPlace', 'birthPlace', 'party')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Abel_Caballero : birthPlace : Spain | Abel_Caballero : birthPlace : Galicia_(Spain) | Abel_Caballero : party : Spanish_Socialist_Workers'_Party <|endoftext|> Abel Caballero was born in Galicia (Spain) and is a member of the Spanish Socialists Workers Party. He is a member of the Spanish Social Workers Party. <|endoftext|>
#
# ['|', 'Abner_W._Sibal', ':', 'battles', ':', 'World_War_II', '|', 'Abner_W._Sibal', ':', 'militaryBranch', ':', 'United_States_Army', '|', 'World_War_II', ':', 'commander', ':', 'Joseph_Stalin']
# ('battles', 'militaryBranch', 'commander')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Abner_W._Sibal : battles : World_War_II | Abner_W._Sibal : militaryBranch : United_States_Army | World_War_II : commander : Joseph_Stalin <|endoftext|> Abner W. Sibal fought in the United States Army during the World War II. The commander of the United States Army is Joseph Stalin. <|endoftext|>
#
# ['|', 'Abner_W._Sibal', ':', 'office', '(workedAt,', 'workedAs)', ':', '"Member', 'of', 'the', 'Connecticut', 'Senate', 'from', 'the', '26th', 'District"', '|', 'Abner_W._Sibal', ':', 'party', ':', 'Republican_Party_(United_States)', '|', 'Abner_W._Sibal', ':', 'birthPlace', ':', 'Ridgewood,_Queens']
# ('office (workedAt, workedAs)', 'party', 'birthPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Abner_W._Sibal : office (workedAt, workedAs) : "Member of the Connecticut Senate from the 26th District" | Abner_W._Sibal : party : Republican_Party_(United_States) | Abner_W._Sibal : birthPlace : Ridgewood,_Queens <|endoftext|> Abner W. Sibal was born in Ridgewood, Queens and worked as a member of the Connecticut Senate from the 26th District. He then went on to work for the Republican Party in the United States. <|endoftext|>
#
# ['|', 'Adam_Holloway', ':', 'battles', ':', 'Gulf_War', '|', 'Gulf_War', ':', 'commander', ':', 'George_H._W._Bush', '|', 'Adam_Holloway', ':', 'militaryBranch', ':', 'Grenadier_Guards']
# ('battles', 'commander', 'militaryBranch')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Adam_Holloway : battles : Gulf_War | Gulf_War : commander : George_H._W._Bush | Adam_Holloway : militaryBranch : Grenadier_Guards <|endoftext|> Adam Holloway fought in the Gulf War, commanded by George H. W. Bush and the Grenadier Guards. <|endoftext|>
#
# ['|', 'Adam_Holloway', ':', 'party', ':', 'Conservative_Party_(UK)', '|', 'Adam_Holloway', ':', 'birthPlace', ':', 'Faversham', '|', 'Adam_Holloway', ':', 'almaMater', ':', 'Magdalene_College,_Cambridge']
# ('party', 'birthPlace', 'almaMater')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Adam_Holloway : party : Conservative_Party_(UK) | Adam_Holloway : birthPlace : Faversham | Adam_Holloway : almaMater : Magdalene_College,_Cambridge <|endoftext|> Adam Holloway was born in Faversham and went to Magdalene College, Cambridge. He attended the Conservative Party (UK). <|endoftext|>
#
# ['|', 'Adam_Koc', ':', 'battles', ':', 'Polish–Soviet_War', '|', 'Adam_Koc', ':', 'birthPlace', ':', 'Congress_Poland', '|', 'Polish–Soviet_War', ':', 'commander', ':', 'Leon_Trotsky']
# ('battles', 'birthPlace', 'commander')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Adam_Koc : battles : Polish–Soviet_War | Adam_Koc : birthPlace : Congress_Poland | Polish–Soviet_War : commander : Leon_Trotsky <|endoftext|> Adam Koc was born in Congress Poland and served as a Polish-Soviet War commander. <|endoftext|>
#
# ['|', 'Adam_Koc', ':', 'battles', ':', 'Polish–Soviet_War', '|', 'Polish–Soviet_War', ':', 'isPartOfMilitaryConflict', ':', 'Russian_Civil_War', '|', 'Polish–Soviet_War', ':', 'commander', ':', 'Leon_Trotsky']
# ('battles', 'isPartOfMilitaryConflict', 'commander')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Adam_Koc : battles : Polish–Soviet_War | Polish–Soviet_War : isPartOfMilitaryConflict : Russian_Civil_War | Polish–Soviet_War : commander : Leon_Trotsky <|endoftext|> Leon Trotsky is the commander of the Polish–Soviet War, which was fought in the Russian Civil War. The Polish–Soviet War is part of the Military Conflicts. <|endoftext|>
#
# ['|', 'Adonis_Georgiadis', ':', 'birthPlace', ':', 'Greece', '|', 'Adonis_Georgiadis', ':', 'office', '(workedAt,', 'workedAs)', ':', '"Deputy', 'Parliamentary', 'Spokesman', 'of', 'Popular', 'Orthodox', 'Rally"', '|', 'Adonis_Georgiadis', ':', 'birthPlace', ':', 'Athens']
# ('birthPlace', 'office (workedAt, workedAs)', 'birthPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Adonis_Georgiadis : birthPlace : Greece | Adonis_Georgiadis : office (workedAt, workedAs) : "Deputy Parliamentary Spokesman of Popular Orthodox Rally" | Adonis_Georgiadis : birthPlace : Athens <|endoftext|> The Deputy Parliamentary Spokesman of Popular Orthodox Rally was Adonis Georgiadis, who was born in Greece and worked as a Parliamentary Spokesman of the Popular Orthodox Rally. <|endoftext|>
#
# ['|', 'Adonis_Georgiadis', ':', 'birthPlace', ':', 'Greece', '|', 'Adonis_Georgiadis', ':', 'office', '(workedAt,', 'workedAs)', ':', '"Minister', 'for', 'Health"', '|', 'Adonis_Georgiadis', ':', 'birthPlace', ':', 'Athens']
# ('birthPlace', 'office (workedAt, workedAs)', 'birthPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Adonis_Georgiadis : birthPlace : Greece | Adonis_Georgiadis : office (workedAt, workedAs) : "Minister for Health" | Adonis_Georgiadis : birthPlace : Athens <|endoftext|> Adonis Georgiadis was born in Greece and worked as a minister for health in Athens before he was born in Adonia. <|endoftext|>
#
# ['|', 'Adonis_Georgiadis', ':', 'inOfficeWhilePrimeMinister', ':', 'Antonis_Samaras', '|', 'New_Democracy_(Greece)', ':', 'colour', ':', 'Blue', '|', 'Adonis_Georgiadis', ':', 'party', ':', 'New_Democracy_(Greece)']
# ('inOfficeWhilePrimeMinister', 'colour', 'party')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Adonis_Georgiadis : inOfficeWhilePrimeMinister : Antonis_Samaras | New_Democracy_(Greece) : colour : Blue | Adonis_Georgiadis : party : New_Democracy_(Greece) <|endoftext|> Adonis Georgiadis is party to New Democracy (Greece) which is the colour of blue. The Prime Minister is Antonis Samaras. <|endoftext|>
#
# ['|', 'Agnes_Kant', ':', 'nationality', ':', 'Netherlands', '|', 'Netherlands', ':', 'leaderName', ':', 'Mark_Rutte', '|', 'Agnes_Kant', ':', 'office', '(workedAt,', 'workedAs)', ':', 'House_of_Representatives_(Netherlands)']
# ('nationality', 'leaderName', 'office (workedAt, workedAs)')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Agnes_Kant : nationality : Netherlands | Netherlands : leaderName : Mark_Rutte | Agnes_Kant : office (workedAt, workedAs) : House_of_Representatives_(Netherlands) <|endoftext|> Agnes Kant is a national of the Netherlands where the House of Representatives is led by Mark Rutte. He worked as a House of Representative. <|endoftext|>
#
# ['|', 'Agnes_Kant', ':', 'nationality', ':', 'Netherlands', '|', 'Netherlands', ':', 'leaderName', ':', 'Mark_Rutte', '|', 'Agnes_Kant', ':', 'party', ':', 'Socialist_Party_(Netherlands)']
# ('nationality', 'leaderName', 'party')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Agnes_Kant : nationality : Netherlands | Netherlands : leaderName : Mark_Rutte | Agnes_Kant : party : Socialist_Party_(Netherlands) <|endoftext|> Agnes Kant is a national of the Netherlands where the leader is Mark Rutte and the party is the Socialist Party. <|endoftext|>
#
# ['|', 'Agnes_Kant', ':', 'office', '(workedAt,', 'workedAs)', ':', '"Member', 'of', 'the', 'House', 'of', 'Representatives"', '|', 'Agnes_Kant', ':', 'birthPlace', ':', 'West_Germany', '|', 'Agnes_Kant', ':', 'almaMater', ':', 'Radboud_University_Nijmegen']
# ('office (workedAt, workedAs)', 'birthPlace', 'almaMater')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Agnes_Kant : office (workedAt, workedAs) : "Member of the House of Representatives" | Agnes_Kant : birthPlace : West_Germany | Agnes_Kant : almaMater : Radboud_University_Nijmegen <|endoftext|> Agnes Kant was born in West Germany and worked as a member of the House of Representatives. He graduated from Radboud University in Nijmegen. <|endoftext|>
#
# ['|', 'Airey_Neave', ':', 'battles', ':', 'World_War_II', '|', 'Airey_Neave', ':', 'activeYearsStartDate', ':', '1953-06-30', '|', 'Airey_Neave', ':', 'activeYearsEndDate', ':', '1979-03-30']
# ('battles', 'activeYearsStartDate', 'activeYearsEndDate')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Airey_Neave : battles : World_War_II | Airey_Neave : activeYearsStartDate : 1953-06-30 | Airey_Neave : activeYearsEndDate : 1979-03-30 <|endoftext|> Airey Neave, which was active for 1953-06-30 and was active for 1979-03-30, was active for World War II. <|endoftext|>
#
# ['|', 'Airey_Neave', ':', 'battles', ':', 'World_War_II', '|', 'Airey_Neave', ':', 'activeYearsStartDate', ':', '1974-03-04', '|', 'Airey_Neave', ':', 'activeYearsEndDate', ':', '1979-03-30']
# ('battles', 'activeYearsStartDate', 'activeYearsEndDate')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Airey_Neave : battles : World_War_II | Airey_Neave : activeYearsStartDate : 1974-03-04 | Airey_Neave : activeYearsEndDate : 1979-03-30 <|endoftext|> Airey Neave is active for 1974-03-04 and has an active years end date of 1979-03-30. It was active in World War II. <|endoftext|>
#
# ['|', 'Albert_B._White', ':', 'deathYear', ':', '1941', '|', 'Albert_B._White', ':', 'birthDate', ':', '1856-09-22', '|', 'Albert_B._White', ':', 'dateOfDeath', ':', '1941-07-03']
# ('deathYear', 'birthDate', 'dateOfDeath')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Albert_B._White : deathYear : 1941 | Albert_B._White : birthDate : 1856-09-22 | Albert_B._White : dateOfDeath : 1941-07-03 <|endoftext|> Albert B. White was born in 1856-09-22 and died in 1941-07-03. <|endoftext|>
#
# ['|', 'Albert_B._White', ':', 'spouse', ':', 'Agnes_Ward_White', '|', 'Agnes_Ward_White', ':', 'birthPlace', ':', 'Marietta,_Ohio', '|', 'Albert_B._White', ':', 'successor', ':', 'William_M._O._Dawson']
# ('spouse', 'birthPlace', 'successor')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Albert_B._White : spouse : Agnes_Ward_White | Agnes_Ward_White : birthPlace : Marietta,_Ohio | Albert_B._White : successor : William_M._O._Dawson <|endoftext|> Marietta, Ohio is the birthplace of Agnes Ward White who married Albert B. White who is the successor of William M. O.Dawson. <|endoftext|>
#
# ['|', 'Albert_Jennings_Fountain', ':', 'birthPlace', ':', 'Staten_Island', '|', 'Albert_Jennings_Fountain', ':', 'deathPlace', ':', 'United_States', '|', 'United_States', ':', 'ethnicGroup', ':', 'African_Americans']
# ('birthPlace', 'deathPlace', 'ethnicGroup')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Albert_Jennings_Fountain : birthPlace : Staten_Island | Albert_Jennings_Fountain : deathPlace : United_States | United_States : ethnicGroup : African_Americans <|endoftext|> Albert Jennings Fountain was born in Staten Island and died in the United States where the African Americans are an ethnic group. <|endoftext|>
#
# ['|', 'Albert_Jennings_Fountain', ':', 'deathPlace', ':', 'New_Mexico_Territory', '|', 'Albert_Jennings_Fountain', ':', 'birthPlace', ':', 'New_York_City', '|', 'Albert_Jennings_Fountain', ':', 'birthPlace', ':', 'Staten_Island']
# ('deathPlace', 'birthPlace', 'birthPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Albert_Jennings_Fountain : deathPlace : New_Mexico_Territory | Albert_Jennings_Fountain : birthPlace : New_York_City | Albert_Jennings_Fountain : birthPlace : Staten_Island <|endoftext|> Albert Jennings Fountain was born in New York City and died in Staten Island. <|endoftext|>
#
# ['|', 'Albert_Jennings_Fountain', ':', 'deathPlace', ':', 'United_States', '|', 'Albert_Jennings_Fountain', ':', 'birthPlace', ':', 'New_York', '|', 'Albert_Jennings_Fountain', ':', 'birthPlace', ':', 'Staten_Island']
# ('deathPlace', 'birthPlace', 'birthPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Albert_Jennings_Fountain : deathPlace : United_States | Albert_Jennings_Fountain : birthPlace : New_York | Albert_Jennings_Fountain : birthPlace : Staten_Island <|endoftext|> Albert Jennings Fountain was born in Staten Island and died in the United States. <|endoftext|>
#
# ['|', 'Alberto_Teisaire', ':', 'deathPlace', ':', 'Buenos_Aires', '|', 'Buenos_Aires', ':', 'governingBody', ':', 'Buenos_Aires_City_Legislature', '|', 'Buenos_Aires', ':', 'leaderName', ':', 'Horacio_Rodríguez_Larreta']
# ('deathPlace', 'governingBody', 'leaderName')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Alberto_Teisaire : deathPlace : Buenos_Aires | Buenos_Aires : governingBody : Buenos_Aires_City_Legislature | Buenos_Aires : leaderName : Horacio_Rodríguez_Larreta <|endoftext|> Horacio Rodríguez Larreta is the leader of Buenos Aires where Alberto Teisaire died. The governing body of Buenos Aires is the Buenos Aires City Legislature. <|endoftext|>
#
# ['|', 'Alberto_Teisaire', ':', 'profession', ':', 'Rear_admiral', '|', 'Alberto_Teisaire', ':', 'successor', ':', 'Isaac_Rojas', '|', 'Alberto_Teisaire', ':', 'birthPlace', ':', 'Mendoza,_Argentina']
# ('profession', 'successor', 'birthPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Alberto_Teisaire : profession : Rear_admiral | Alberto_Teisaire : successor : Isaac_Rojas | Alberto_Teisaire : birthPlace : Mendoza,_Argentina <|endoftext|> Alberto Teisaire was born in Mendoza, Argentina and was a Rear admiral. Isaac Rojas was his successor. <|endoftext|>
#
# ['|', 'Alfons_Gorbach', ':', 'deathPlace', ':', 'Graz', '|', 'Alfons_Gorbach', ':', 'birthPlace', ':', 'County_of_Tyrol', '|', 'Alfons_Gorbach', ':', 'birthPlace', ':', 'Austria']
# ('deathPlace', 'birthPlace', 'birthPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Alfons_Gorbach : deathPlace : Graz | Alfons_Gorbach : birthPlace : County_of_Tyrol | Alfons_Gorbach : birthPlace : Austria <|endoftext|> Alfons Gorbach was born in Austria and died in Graz. He was born in the County of Tyrol. <|endoftext|>
#
# ['|', 'Alfred_N._Phillips', ':', 'successor', ':', 'Albert_E._Austin', '|', 'Alfred_N._Phillips', ':', 'birthPlace', ':', 'Connecticut', '|', 'Alfred_N._Phillips', ':', 'office', '(workedAt,', 'workedAs)', ':', '"Member', 'of', 'the', 'U.S.', 'House', 'of', 'Representatives', 'from', "Connecticut's", '4th', 'district"']
# ('successor', 'birthPlace', 'office (workedAt, workedAs)')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Alfred_N._Phillips : successor : Albert_E._Austin | Alfred_N._Phillips : birthPlace : Connecticut | Alfred_N._Phillips : office (workedAt, workedAs) : "Member of the U.S. House of Representatives from Connecticut's 4th district" <|endoftext|> Alfred N. Phillips was born in Connecticut and worked as a member of the U.S. House of Representatives from Connecticut's 4th district. His successor was Albert E. Austin. <|endoftext|>
#
# ['|', 'Alfred_N._Phillips', ':', 'successor', ':', 'Albert_E._Austin', '|', 'Alfred_N._Phillips', ':', 'birthPlace', ':', 'Darien,_Connecticut', '|', 'Alfred_N._Phillips', ':', 'office', '(workedAt,', 'workedAs)', ':', '"Member', 'of', 'the', 'U.S.', 'House', 'of', 'Representatives', 'from', "Connecticut's", '4th', 'district"']
# ('successor', 'birthPlace', 'office (workedAt, workedAs)')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Alfred_N._Phillips : successor : Albert_E._Austin | Alfred_N._Phillips : birthPlace : Darien,_Connecticut | Alfred_N._Phillips : office (workedAt, workedAs) : "Member of the U.S. House of Representatives from Connecticut's 4th district" <|endoftext|> Alfred N. Phillips was born in Darien,Connecticut and worked as a member of the U.S. House of Representatives from Connecticut's 4th district. His successor was Albert E. Austin. <|endoftext|>
#
# ['|', 'Allan_Shivers', ':', 'office', '(workedAt,', 'workedAs)', ':', '"Member', 'of', 'the', 'Texas', 'State', 'Senate', 'from', 'District', '4', '(Port', 'Arthur)"', '|', 'Allan_Shivers', ':', 'party', ':', 'Democratic_Party_(United_States)', '|', 'Allan_Shivers', ':', 'successor', ':', 'Wilfred_R._Cousins,_Jr.']
# ('office (workedAt, workedAs)', 'party', 'successor')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Allan_Shivers : office (workedAt, workedAs) : "Member of the Texas State Senate from District 4 (Port Arthur)" | Allan_Shivers : party : Democratic_Party_(United_States) | Allan_Shivers : successor : Wilfred_R._Cousins,_Jr. <|endoftext|> Allan Shivers was a member of the Texas State Senate from District 4 (Port Arthur) and worked as a member of the Texas State Senate. His successor was Wilfred R. Cousins Jr. <|endoftext|>
#
# ['|', 'Alvah_Sabin', ':', 'activeYearsEndDate', ':', '1857-03-03', '|', 'Alvah_Sabin', ':', 'region', ':', 'Vermont', '|', 'Vermont', ':', 'largestCity', ':', 'Burlington,_Vermont']
# ('activeYearsEndDate', 'region', 'largestCity')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Alvah_Sabin : activeYearsEndDate : 1857-03-03 | Alvah_Sabin : region : Vermont | Vermont : largestCity : Burlington,_Vermont <|endoftext|> Alvah Sabin, who was active for 1857-03-03, was a member of the Vermont region, which has Burlington as its largest city. <|endoftext|>
#
# ['|', 'Alvah_Sabin', ':', 'party', ':', 'Whig_Party_(United_States)', '|', 'Alvah_Sabin', ':', 'birthDate', ':', '1793-10-23', '|', 'Whig_Party_(United_States)', ':', 'leaderName', ':', 'Henry_Clay']
# ('party', 'birthDate', 'leaderName')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Alvah_Sabin : party : Whig_Party_(United_States) | Alvah_Sabin : birthDate : 1793-10-23 | Whig_Party_(United_States) : leaderName : Henry_Clay <|endoftext|> Alvah Sabin was born in 1793-10-23 in the United States. He attended the Whig Party which was led by Henry Clay. <|endoftext|>
#
# ['|', 'Alvah_Sabin', ':', 'party', ':', 'Whig_Party_(United_States)', '|', 'Whig_Party_(United_States)', ':', 'leaderName', ':', 'Daniel_Webster', '|', 'Alvah_Sabin', ':', 'birthPlace', ':', 'Georgia,_Vermont']
# ('party', 'leaderName', 'birthPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Alvah_Sabin : party : Whig_Party_(United_States) | Whig_Party_(United_States) : leaderName : Daniel_Webster | Alvah_Sabin : birthPlace : Georgia,_Vermont <|endoftext|> Alvah Sabin was born in Georgia, Vermont and attended the Whig Party which was led by Daniel Webster. <|endoftext|>
#
# ['|', 'American_Civil_War', ':', 'commander', ':', 'Abraham_Lincoln', '|', 'Albert_Jennings_Fountain', ':', 'battles', ':', 'American_Civil_War', '|', 'Albert_Jennings_Fountain', ':', 'birthPlace', ':', 'United_States']
# ('commander', 'battles', 'birthPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | American_Civil_War : commander : Abraham_Lincoln | Albert_Jennings_Fountain : battles : American_Civil_War | Albert_Jennings_Fountain : birthPlace : United_States <|endoftext|> Albert Jennings Fountain was born in the United States and served as a commander in the American Civil War. <|endoftext|>
#
# ['|', 'American_Civil_War', ':', 'commander', ':', 'Jefferson_Davis', '|', 'Alfred_Moore_Scales', ':', 'battles', ':', 'Battle_of_Fredericksburg', '|', 'Battle_of_Fredericksburg', ':', 'isPartOfMilitaryConflict', ':', 'American_Civil_War']
# ('commander', 'battles', 'isPartOfMilitaryConflict')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | American_Civil_War : commander : Jefferson_Davis | Alfred_Moore_Scales : battles : Battle_of_Fredericksburg | Battle_of_Fredericksburg : isPartOfMilitaryConflict : American_Civil_War <|endoftext|> Battle of Fredericksburg is part of the American Civil War, which was commanded by Jefferson Davis. <|endoftext|>
#
# ['|', 'Austria', ':', 'leaderName', ':', 'Doris_Bures', '|', 'Alfons_Gorbach', ':', 'birthPlace', ':', 'County_of_Tyrol', '|', 'Alfons_Gorbach', ':', 'deathPlace', ':', 'Austria']
# ('leaderName', 'birthPlace', 'deathPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Austria : leaderName : Doris_Bures | Alfons_Gorbach : birthPlace : County_of_Tyrol | Alfons_Gorbach : deathPlace : Austria <|endoftext|> Alfons Gorbach, born in Tyrol, died in Austria where the leader is Doris Bures. <|endoftext|>
#
# ['|', 'Austria', ':', 'leaderName', ':', 'Doris_Bures', '|', 'Alfons_Gorbach', ':', 'birthPlace', ':', 'Tyrol_(state)', '|', 'Alfons_Gorbach', ':', 'deathPlace', ':', 'Austria']
# ('leaderName', 'birthPlace', 'deathPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Austria : leaderName : Doris_Bures | Alfons_Gorbach : birthPlace : Tyrol_(state) | Alfons_Gorbach : deathPlace : Austria <|endoftext|> Alfons Gorbach was born in Tyrol (state) and died in Austria whose leader is Doris Bures. <|endoftext|>
#
# ['|', 'Austria', ':', 'leaderName', ':', 'Doris_Bures', '|', 'Alfons_Gorbach', ':', 'deathPlace', ':', 'Styria', '|', 'Alfons_Gorbach', ':', 'deathPlace', ':', 'Austria']
# ('leaderName', 'deathPlace', 'deathPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Austria : leaderName : Doris_Bures | Alfons_Gorbach : deathPlace : Styria | Alfons_Gorbach : deathPlace : Austria <|endoftext|> Alfons Gorbach died in Styria in Austria where the leader is Doris Bures. <|endoftext|>
#
# ['|', 'Battle_of_Salem_Church', ':', 'commander', ':', 'Robert_E._Lee', '|', 'Battle_of_Salem_Church', ':', 'isPartOfMilitaryConflict', ':', 'American_Civil_War', '|', 'Aaron_S._Daggett', ':', 'battles', ':', 'Battle_of_Salem_Church']
# ('commander', 'isPartOfMilitaryConflict', 'battles')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Battle_of_Salem_Church : commander : Robert_E._Lee | Battle_of_Salem_Church : isPartOfMilitaryConflict : American_Civil_War | Aaron_S._Daggett : battles : Battle_of_Salem_Church <|endoftext|> The Battle of Salem Church is part of the American Civil War and the commander was Robert E. Lee. Aaron S. Dotgett also fought in the Battle of Salem Church. <|endoftext|>
#
# ['|', 'Netherlands', ':', 'currency', ':', 'Euro', '|', 'Ab_Klink', ':', 'birthPlace', ':', 'Stellendam', '|', 'Ab_Klink', ':', 'nationality', ':', 'Netherlands']
# ('currency', 'birthPlace', 'nationality')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Netherlands : currency : Euro | Ab_Klink : birthPlace : Stellendam | Ab_Klink : nationality : Netherlands <|endoftext|> Ab Klink was born in Stellendam and is a national of the Netherlands, where the Euro is the currency. <|endoftext|>
#
# ['|', 'Poland', ':', 'language', ':', 'Polish_language', '|', 'Adam_Koc', ':', 'nationality', ':', 'Poland', '|', 'Poland', ':', 'ethnicGroup', ':', 'Kashubians']
# ('language', 'nationality', 'ethnicGroup')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Poland : language : Polish_language | Adam_Koc : nationality : Poland | Poland : ethnicGroup : Kashubians <|endoftext|> Adam Koc is a national of Poland, where the language is Polish and the ethnic group is the Kashubians. <|endoftext|>
#
# ['|', '(19255)_1994_VK8', ':', 'escapeVelocity', ':', '0.0925', '(kilometrePerSeconds)', '|', '(19255)_1994_VK8', ':', 'mass', ':', '5.6', '(kilograms)', '|', '(19255)_1994_VK8', ':', 'apoapsis', ':', '6603633000.0', '(kilometres)']
# ('escapeVelocity', 'mass', 'apoapsis')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | (19255)_1994_VK8 : escapeVelocity : 0.0925 (kilometrePerSeconds) | (19255)_1994_VK8 : mass : 5.6 (kilograms) | (19255)_1994_VK8 : apoapsis : 6603633000.0 (kilometres) <|endoftext|> The escape velocity of the 19255 1994 VK8 is 0.0925 (kilometre per second) and the apoapsis is 6603633000.0 (kilometres). <|endoftext|>
#
# ['|', '(410777)_2009_FD', ':', 'orbitalPeriod', ':', '39447000.0', '|', '(410777)_2009_FD', ':', 'periapsis', ':', '88234300000.0', '|', '(410777)_2009_FD', ':', 'discoverer', ':', 'Spacewatch']
# ('orbitalPeriod', 'periapsis', 'discoverer')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | (410777)_2009_FD : orbitalPeriod : 39447000.0 | (410777)_2009_FD : periapsis : 88234300000.0 | (410777)_2009_FD : discoverer : Spacewatch <|endoftext|> 410777, who was the discoverer of 410777 is the discoverer of Spacewatch and the periapsis period of 39447000.0. <|endoftext|>
#
# ['|', '(66063)_1998_RO1', ':', 'minimumTemperature', ':', '-71.0', '(degreeCelsius)', '|', '(66063)_1998_RO1', ':', 'maximumTemperature', ':', '500.0', '(kelvins)', '|', '(66063)_1998_RO1', ':', 'apoapsis', ':', '254989570.60815', '(kilometres)']
# ('minimumTemperature', 'maximumTemperature', 'apoapsis')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | (66063)_1998_RO1 : minimumTemperature : -71.0 (degreeCelsius) | (66063)_1998_RO1 : maximumTemperature : 500.0 (kelvins) | (66063)_1998_RO1 : apoapsis : 254989570.60815 (kilometres) <|endoftext|> The minimum and maximum temperatures of the apoapsis and the minimum and maximum temperatures of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum and maximum of the minimum
#
# ['|', '(66391)_1999_KW4', ':', 'averageSpeed', ':', '37.16', '(kilometrePerSeconds)', '|', '(66391)_1999_KW4', ':', 'density', ':', '2.0', '(gramPerCubicCentimetres)', '|', '(66391)_1999_KW4', ':', 'apoapsis', ':', '162164091.8388', '(kilometres)']
# ('averageSpeed', 'density', 'apoapsis')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | (66391)_1999_KW4 : averageSpeed : 37.16 (kilometrePerSeconds) | (66391)_1999_KW4 : density : 2.0 (gramPerCubicCentimetres) | (66391)_1999_KW4 : apoapsis : 162164091.8388 (kilometres) <|endoftext|> Apoapsis is 162164091.8388 (kilometres) and the average speed of a 66391 is 37.16 (kilometre per second). <|endoftext|>
#
# ['|', '1000_Piazzia', ':', 'orbitalPeriod', ':', '488160.0', '|', '1000_Piazzia', ':', 'periapsis', ':', '352497000000.0', '|', '1000_Piazzia', ':', 'epoch', ':', '2015-06-27']
# ('orbitalPeriod', 'periapsis', 'epoch')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | 1000_Piazzia : orbitalPeriod : 488160.0 | 1000_Piazzia : periapsis : 352497000000.0 | 1000_Piazzia : epoch : 2015-06-27 <|endoftext|> 1000 Piazzia, which has an orbital period of 488160.0 and periapsis of 352497000000.0, was published in 2015. <|endoftext|>
#
# ['|', '1001_Gaussia', ':', 'epoch', ':', '2015-06-27', '|', '1001_Gaussia', ':', 'formerName', ':', '"1923', 'OAA907', 'XC"', '|', '1001_Gaussia', ':', 'periapsis', ':', '419113394.55312', '(kilometres)']
# ('epoch', 'formerName', 'periapsis')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | 1001_Gaussia : epoch : 2015-06-27 | 1001_Gaussia : formerName : "1923 OAA907 XC" | 1001_Gaussia : periapsis : 419113394.55312 (kilometres) <|endoftext|> 1001 Gaussia, which is now known as "1923 OAA907 XC" was formerly known as "The 1923 OAA907 XC" and has the periapsis of 419113394.55312 Kilometres. <|endoftext|>
#
# ['|', '101_Helena', ':', 'mass', ':', '3.0', '(kilograms)', '|', '101_Helena', ':', 'escapeVelocity', ':', '0.0348', '(kilometrePerSeconds)', '|', '101_Helena', ':', 'apoapsis', ':', '441092000.0', '(kilometres)']
# ('mass', 'escapeVelocity', 'apoapsis')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | 101_Helena : mass : 3.0 (kilograms) | 101_Helena : escapeVelocity : 0.0348 (kilometrePerSeconds) | 101_Helena : apoapsis : 441092000.0 (kilometres) <|endoftext|> 101 Helena is 3.0 kilogram and apoapsis is 441092000.0. <|endoftext|>
#
# ['|', '1036_Ganymed', ':', 'discoverer', ':', 'Walter_Baade', '|', 'Walter_Baade', ':', 'nationality', ':', 'Germany', '|', 'Walter_Baade', ':', 'almaMater', ':', 'University_of_Göttingen']
# ('discoverer', 'nationality', 'almaMater')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | 1036_Ganymed : discoverer : Walter_Baade | Walter_Baade : nationality : Germany | Walter_Baade : almaMater : University_of_Göttingen <|endoftext|> Walter Baade is a national of Germany and was the discoverer of the 1036 Ganymed. He graduated from the University of Göttingen. <|endoftext|>
#
# ['|', '103_Hera', ':', 'discoverer', ':', 'James_Craig_Watson', '|', '103_Hera', ':', 'epoch', ':', '2011-08-27', '|', 'James_Craig_Watson', ':', 'deathPlace', ':', 'Madison,_Wisconsin']
# ('discoverer', 'epoch', 'deathPlace')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | 103_Hera : discoverer : James_Craig_Watson | 103_Hera : epoch : 2011-08-27 | James_Craig_Watson : deathPlace : Madison,_Wisconsin <|endoftext|> James Craig Watson, who died in Madison, Wisconsin, in 2011, was the discoverer of 103 Hastings. <|endoftext|>
#
# ['|', '103_Hera', ':', 'discoverer', ':', 'James_Craig_Watson', '|', 'James_Craig_Watson', ':', 'deathPlace', ':', 'Madison,_Wisconsin', '|', 'James_Craig_Watson', ':', 'deathCause', ':', 'Peritonitis']
# ('discoverer', 'deathPlace', 'deathCause')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
# ...
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Andrew_Rayel : associatedBand/associatedMusicalArtist : Armin_van_Buuren | Andrew_Rayel : associatedBand/associatedMusicalArtist : Bobina | Andrew_Rayel : associatedBand/associatedMusicalArtist : "Armin Van Buuren, Bobina, Mark Sixma, Jonathan Mendelsohn, Christian Burns, Jwaydan, Alexander Popov, Jano, Alexandre Bergheau, Jonny Rose, Sylvia Tosun, Lira Yin, Alexandra Badoi" | Andrew_Rayel : genre : Trance_music | Trance_music : stylisticOrigin : Pop_music <|endoftext|> Andrew Rayel is associated with Armin Van Buuren, Bobina, Mark Sixma, Jonathan Mendelsohn, Christian Burns, Jwaydan, Alexander Popov, Jano, Alexandre Bergheau, Jonny Rose, Sylvia Tosun, Lira Yin, Alexandra Badoi and Trance music. <|endoftext|>
#
# ['|', 'Andrew_Rayel', ':', 'associatedBand/associatedMusicalArtist', ':', 'Christian_Burns', '|', 'Andrew_Rayel', ':', 'genre', ':', 'Trance_music', '|', 'Andrew_Rayel', ':', 'associatedBand/associatedMusicalArtist', ':', 'Armin_van_Buuren', '|', 'Andrew_Rayel', ':', 'birthPlace', ':', '"Chișinău,', 'Moldova"', '|', 'Andrew_Rayel', ':', 'activeYearsStartYear', ':', '2009']
# ('associatedBand/associatedMusicalArtist', 'genre', 'associatedBand/associatedMusicalArtist', 'birthPlace', 'activeYearsStartYear')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Andrew_Rayel : associatedBand/associatedMusicalArtist : Christian_Burns | Andrew_Rayel : genre : Trance_music | Andrew_Rayel : associatedBand/associatedMusicalArtist : Armin_van_Buuren | Andrew_Rayel : birthPlace : "Chișinău, Moldova" | Andrew_Rayel : activeYearsStartYear : 2009 <|endoftext|> Andrew Rayel was born in Chișinău, Moldova. He was a member of the Armin van Buuren and Christian Burns based Trance music. He was a member of the associated band Chișinău based on the genre of Trance music. He was active in 2009. <|endoftext|>
#
# ['|', 'Andrew_Rayel', ':', 'associatedBand/associatedMusicalArtist', ':', 'Jwaydan_Moyine', '|', 'Andrew_Rayel', ':', 'associatedBand/associatedMusicalArtist', ':', 'Bobina', '|', 'Andrew_Rayel', ':', 'genre', ':', 'Trance_music', '|', 'Andrew_Rayel', ':', 'birthPlace', ':', '"Chișinău,', 'Moldova"', '|', 'Andrew_Rayel', ':', 'activeYearsStartYear', ':', '2009']
# ('associatedBand/associatedMusicalArtist', 'associatedBand/associatedMusicalArtist', 'genre', 'birthPlace', 'activeYearsStartYear')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Andrew_Rayel : associatedBand/associatedMusicalArtist : Jwaydan_Moyine | Andrew_Rayel : associatedBand/associatedMusicalArtist : Bobina | Andrew_Rayel : genre : Trance_music | Andrew_Rayel : birthPlace : "Chișinău, Moldova" | Andrew_Rayel : activeYearsStartYear : 2009 <|endoftext|> Andrew Rayel was born in Chișinău, Moldova. He was a member of the associated band called Chișinău, he was a member of the Trance music genre and he has been active since 2009. <|endoftext|>
#
# ['|', 'Andrew_Rayel', ':', 'associatedBand/associatedMusicalArtist', ':', 'Jwaydan_Moyine', '|', 'Jwaydan_Moyine', ':', 'associatedBand/associatedMusicalArtist', ':', 'John_Digweed', '|', 'Andrew_Rayel', ':', 'instrument', ':', 'String_instrument', '|', 'Andrew_Rayel', ':', 'associatedBand/associatedMusicalArtist', ':', 'Christian_Burns', '|', 'Andrew_Rayel', ':', 'genre', ':', 'Trance_music']
# ('associatedBand/associatedMusicalArtist', 'associatedBand/associatedMusicalArtist', 'instrument', 'associatedBand/associatedMusicalArtist', 'genre')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Andrew_Rayel : associatedBand/associatedMusicalArtist : Jwaydan_Moyine | Jwaydan_Moyine : associatedBand/associatedMusicalArtist : John_Digweed | Andrew_Rayel : instrument : String_instrument | Andrew_Rayel : associatedBand/associatedMusicalArtist : Christian_Burns | Andrew_Rayel : genre : Trance_music <|endoftext|> Andrew Rayel is a member of the associated music genre of Trance music. He is also associated with John Digweed and Christian Burns. <|endoftext|>
#
# ['|', 'Andrew_White_(musician)', ':', 'associatedBand/associatedMusicalArtist', ':', 'Kaiser_Chiefs', '|', 'Andrew_White_(musician)', ':', 'associatedBand/associatedMusicalArtist', ':', 'Marry_Banilow', '|', 'Andrew_White_(musician)', ':', 'recordLabel', ':', 'B-Unique_Records', '|', 'Andrew_White_(musician)', ':', 'recordLabel', ':', 'Polydor_Records', '|', 'Andrew_White_(musician)', ':', 'activeYearsStartYear', ':', '2003']
# ('associatedBand/associatedMusicalArtist', 'associatedBand/associatedMusicalArtist', 'recordLabel', 'recordLabel', 'activeYearsStartYear')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Andrew_White_(musician) : associatedBand/associatedMusicalArtist : Kaiser_Chiefs | Andrew_White_(musician) : associatedBand/associatedMusicalArtist : Marry_Banilow | Andrew_White_(musician) : recordLabel : B-Unique_Records | Andrew_White_(musician) : recordLabel : Polydor_Records | Andrew_White_(musician) : activeYearsStartYear : 2003 <|endoftext|> Andrew White is a musician who was a member of the Kaiser Chiefs and Marry Banilow. He also performed in the band Polydor Records and released records under the label B-Unique Records. He was active in the following bands: Kaiser Chiefs and Marry Banilow. <|endoftext|>
#
# ['|', 'Hip_hop_music', ':', 'stylisticOrigin', ':', 'Disco', '|', 'Allen_Forrest', ':', 'birthPlace', ':', 'Fort_Campbell', '|', 'Allen_Forrest', ':', 'genre', ':', 'Hip_hop_music', '|', 'Hip_hop_music', ':', 'stylisticOrigin', ':', 'Funk', '|', 'Hip_hop_music', ':', 'derivative', ':', 'Drum_and_bass']
# ('stylisticOrigin', 'birthPlace', 'genre', 'stylisticOrigin', 'derivative')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Hip_hop_music : stylisticOrigin : Disco | Allen_Forrest : birthPlace : Fort_Campbell | Allen_Forrest : genre : Hip_hop_music | Hip_hop_music : stylisticOrigin : Funk | Hip_hop_music : derivative : Drum_and_bass <|endoftext|> Allen Forrest was born in Fort Campbell. He is a Hip Hop music fan, whose genre is Hip Hop and whose derivative is Drum and bass. <|endoftext|>
#
# ['|', 'Hip_hop_music', ':', 'stylisticOrigin', ':', 'Disco', '|', 'Allen_Forrest', ':', 'genre', ':', 'Hip_hop_music', '|', 'Allen_Forrest', ':', 'birthYear', ':', '1981', '|', 'Hip_hop_music', ':', 'stylisticOrigin', ':', 'Funk', '|', 'Hip_hop_music', ':', 'derivative', ':', 'Drum_and_bass']
# ('stylisticOrigin', 'genre', 'birthYear', 'stylisticOrigin', 'derivative')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Hip_hop_music : stylisticOrigin : Disco | Allen_Forrest : genre : Hip_hop_music | Allen_Forrest : birthYear : 1981 | Hip_hop_music : stylisticOrigin : Funk | Hip_hop_music : derivative : Drum_and_bass <|endoftext|> Allen Forrest was born in 1981. He is a Hiphop music fan, whose genre is Hip Hop, whose origin is Disco and whose derivative is Drum and bass. <|endoftext|>
#
# ['|', 'London', ':', 'leaderTitle', ':', 'Parliament_of_the_United_Kingdom', '|', 'Alfred_Garth_Jones', ':', 'deathPlace', ':', 'Sidcup', '|', 'Alfred_Garth_Jones', ':', 'deathPlace', ':', 'London', '|', 'Alfred_Garth_Jones', ':', 'birthPlace', ':', 'Manchester', '|', 'Manchester', ':', 'leaderName', ':', 'Labour_Party_(UK)']
# ('leaderTitle', 'deathPlace', 'deathPlace', 'birthPlace', 'leaderName')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | London : leaderTitle : Parliament_of_the_United_Kingdom | Alfred_Garth_Jones : deathPlace : Sidcup | Alfred_Garth_Jones : deathPlace : London | Alfred_Garth_Jones : birthPlace : Manchester | Manchester : leaderName : Labour_Party_(UK) <|endoftext|> Alfred Garth Jones was born in Manchester and died in London. He was a member of the Parliament of the United Kingdom and was a member of the Labour Party (UK). <|endoftext|>
#
# ['|', 'Paraguay', ':', 'ethnicGroup', ':', 'Mestizo', '|', 'Agustín_Barboza', ':', 'birthPlace', ':', 'Asunción', '|', 'Paraguay', ':', 'leaderName', ':', 'Juan_Afara', '|', 'Agustín_Barboza', ':', 'deathPlace', ':', 'Paraguay', '|', 'Paraguay', ':', 'language', ':', 'Spanish_language']
# ('ethnicGroup', 'birthPlace', 'leaderName', 'deathPlace', 'language')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Paraguay : ethnicGroup : Mestizo | Agustín_Barboza : birthPlace : Asunción | Paraguay : leaderName : Juan_Afara | Agustín_Barboza : deathPlace : Paraguay | Paraguay : language : Spanish_language <|endoftext|> Agustín Barboza was born in Asunción and died in Paraguay, where the leader is Juan Afara and the language is Spanish. <|endoftext|>
#
# ['|', 'Polydor_Records', ':', 'location', ':', 'London', '|', 'Alternative_rock', ':', 'musicFusionGenre', ':', 'Nu_metal', '|', 'Andrew_White_(musician)', ':', 'genre', ':', 'Alternative_rock', '|', 'Andrew_White_(musician)', ':', 'recordLabel', ':', 'B-Unique_Records', '|', 'Andrew_White_(musician)', ':', 'recordLabel', ':', 'Polydor_Records']
# ('location', 'musicFusionGenre', 'genre', 'recordLabel', 'recordLabel')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Polydor_Records : location : London | Alternative_rock : musicFusionGenre : Nu_metal | Andrew_White_(musician) : genre : Alternative_rock | Andrew_White_(musician) : recordLabel : B-Unique_Records | Andrew_White_(musician) : recordLabel : Polydor_Records <|endoftext|> Andrew White is a musician who performs in the genre of Nu metal and alternative rock. He has a record label called B-Unique Records and also a record label called Polydor Records. <|endoftext|>
#
# ['|', 'Polydor_Records', ':', 'location', ':', 'London', '|', 'Alternative_rock', ':', 'musicFusionGenre', ':', 'Nu_metal', '|', 'Andrew_White_(musician)', ':', 'recordLabel', ':', 'Polydor_Records', '|', 'Andrew_White_(musician)', ':', 'recordLabel', ':', 'Universal_Records_(defunct_record_label)', '|', 'Andrew_White_(musician)', ':', 'genre', ':', 'Alternative_rock']
# ('location', 'musicFusionGenre', 'recordLabel', 'recordLabel', 'genre')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Polydor_Records : location : London | Alternative_rock : musicFusionGenre : Nu_metal | Andrew_White_(musician) : recordLabel : Polydor_Records | Andrew_White_(musician) : recordLabel : Universal_Records_(defunct_record_label) | Andrew_White_(musician) : genre : Alternative_rock <|endoftext|> Polydor Records is located in London and is the location of the Alternative rock genre. Nu metal is one of the genres of the record label Universal Records and the defunct record label Polydor Records. Andrew White is a musician who performs in this genre. <|endoftext|>
#
# ['|', 'Rock_music', ':', 'musicFusionGenre', ':', 'Bhangra_(music)', '|', 'Al_Anderson_(NRBQ', 'band)', ':', 'instrument', ':', 'Guitar', '|', 'Al_Anderson_(NRBQ', 'band)', ':', 'genre', ':', 'Rock_music', '|', 'Rock_music', ':', 'stylisticOrigin', ':', 'Country_music', '|', 'Country_music', ':', 'stylisticOrigin', ':', 'Blues']
# ('musicFusionGenre', 'instrument', 'genre', 'stylisticOrigin', 'stylisticOrigin')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Rock_music : musicFusionGenre : Bhangra_(music) | Al_Anderson_(NRBQ band) : instrument : Guitar | Al_Anderson_(NRBQ band) : genre : Rock_music | Rock_music : stylisticOrigin : Country_music | Country_music : stylisticOrigin : Blues <|endoftext|> Al Anderson (NRBQ band) is a rock music originates from the country of Bhangra. Their instrument is the guitar and their rock music originates from the blues genre. <|endoftext|>
#
# ['|', 'Rock_music', ':', 'stylisticOrigin', ':', 'Blues', '|', 'Rock_music', ':', 'musicFusionGenre', ':', 'Bhangra_(music)', '|', 'Country_music', ':', 'instrument', ':', 'Banjo', '|', 'Al_Anderson_(NRBQ', 'band)', ':', 'genre', ':', 'Rock_music', '|', 'Rock_music', ':', 'stylisticOrigin', ':', 'Country_music']
# ('stylisticOrigin', 'musicFusionGenre', 'instrument', 'genre', 'stylisticOrigin')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Rock_music : stylisticOrigin : Blues | Rock_music : musicFusionGenre : Bhangra_(music) | Country_music : instrument : Banjo | Al_Anderson_(NRBQ band) : genre : Rock_music | Rock_music : stylisticOrigin : Country_music <|endoftext|> Al Anderson (NRBQ band) is a rock music originates from Bhangra (country music) and rock music is a fusion genre of country music. <|endoftext|>
#
# ['|', 'Twilight_(band)', ':', 'genre', ':', 'Black_metal', '|', 'Aaron_Turner', ':', 'associatedBand/associatedMusicalArtist', ':', 'Twilight_(band)', '|', 'Aaron_Turner', ':', 'associatedBand/associatedMusicalArtist', ':', 'Old_Man_Gloom', '|', 'Aaron_Turner', ':', 'instrument', ':', 'Electric_guitar', '|', 'Black_metal', ':', 'musicFusionGenre', ':', 'Death_metal']
# ('genre', 'associatedBand/associatedMusicalArtist', 'associatedBand/associatedMusicalArtist', 'instrument', 'musicFusionGenre')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Twilight_(band) : genre : Black_metal | Aaron_Turner : associatedBand/associatedMusicalArtist : Twilight_(band) | Aaron_Turner : associatedBand/associatedMusicalArtist : Old_Man_Gloom | Aaron_Turner : instrument : Electric_guitar | Black_metal : musicFusionGenre : Death_metal <|endoftext|> Aaron Turner is associated with the Black metal genre of death metal. He also performs with the electric guitar and Old Man Gloom. <|endoftext|>
#
# ['|', 'Uruguay', ':', 'leaderName', ':', 'Raúl_Fernando_Sendic_Rodríguez', '|', 'Alfredo_Zitarrosa', ':', 'deathPlace', ':', 'Montevideo', '|', 'Montevideo', ':', 'country', ':', 'Uruguay', '|', 'Montevideo', ':', 'leaderName', ':', 'Daniel_Martínez_(politician)', '|', 'Uruguay', ':', 'language', ':', 'Spanish_language']
# ('leaderName', 'deathPlace', 'country', 'leaderName', 'language')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#   | Uruguay : leaderName : Raúl_Fernando_Sendic_Rodríguez | Alfredo_Zitarrosa : deathPlace : Montevideo | Montevideo : country : Uruguay | Montevideo : leaderName : Daniel_Martínez_(politician) | Uruguay : language : Spanish_language <|endoftext|> Raúl Fernando Sendic Rodríguez is the leader of Uruguay where the Spanish language is spoken. Daniel Martinez is a political leader and Alfredo Zitarrosa died in Montevideo. <|endoftext|>
#
# /content/PrefixTuning/gpt2/webnlg_models/webnlgprefixtune_y_5_act_cat_b=5-e=5_d=0.0_u=no_lr=5e-05_w=0.0_s=222_r=n_m=512_earlystop_o=1_o=1-checkpoint-15000_test_beam_eval
#  /content/PrefixTuning/gpt2/webnlg_models/webnlgprefixtune_y_5_act_cat_b=5-e=5_d=0.0_u=no_lr=5e-05_w=0.0_s=222_r=n_m=512_earlystop_o=1_o=1-checkpoint-15000_test_gold
#  /content/PrefixTuning/gpt2/webnlg_models/webnlgprefixtune_y_5_act_cat_b=5-e=5_d=0.0_u=no_lr=5e-05_w=0.0_s=222_r=n_m=512_earlystop_o=1_o=1-checkpoint-15000_test_beam
# Time taken: 9493.599076509476 seconds

# %%
# !bash ../../dart/evaluation/run_eval_on_webnlg.sh
# Out:
# webnlg_models/webnlgprefixtune_y_5_act_cat_b=5-e=5_d=0.0_u=no_lr=5e-05_w=0.0_s=222_r=n_m=512_earlystop_o=1_o=1_test_beam
# team
# Gold count 1862
# reduced (new) 891
# reduced (old) 971
# Files creating finished for:  team
# Calculating BLEU for:
# team
# all-cat
# old-cat
# new-cat
# MeanOfTransportation
# University
# Monument
# Astronaut
# ComicsCharacter
# Airport
# Food
# SportsTeam
# City
# Building
# Politician
# Athlete
# Artist
# CelestialBody
# WrittenWork
# 4size
# 5size
# 6size
# 7size
# 1size
# 2size
# 3size
# ALL:
# SEEN:
# UNSEEN:
# This script should be run from the directory where METEOR is installed. Modify your GLOBAL_PATH accordingly.
# team
# all-cat
# old-cat
# new-cat
# MeanOfTransportation
# University
# Monument
# Astronaut
# ComicsCharacter
# Airport
# Food
# SportsTeam
# City
# Building
# Politician
# Athlete
# Artist
# CelestialBody
# WrittenWork
# 1size
# 2size
# 3size
# 4size
# 5size
# 6size
# 7size
# ALL:
# SEEN:
# UNSEEN:
# This script should be run from the directory where TER is installed. Modify your GLOBAL_PATH accordingly.
# team
# all-cat
# old-cat
# new-cat
# MeanOfTransportation
# University
# Monument
# Astronaut
# ComicsCharacter
# Airport
# Food
# SportsTeam
# City
# Building
# Politician
# Athlete
# Artist
# CelestialBody
# WrittenWork
# 4size
# 5size
# 6size
# 7size
# 1size
# 2size
# 3size
# ALL:
# SEEN:
# UNSEEN:
# ##################### Summary ##########################
# BLEU Seen: 62.68
# BLEU Unseen: 43.48
# BLEU All: 54.01
# METEOR Seen: 0.44
# METEOR Unseen: 0.37
# METEOR All: 0.41
# TER Seen: 0.35
# TER Unseen: 0.51
# TER All: 0.41
# 62.68 & 43.48 & 54.01 & 0.44 & 0.37 & 0.41 & 0.35 & 0.51 & 0.41
