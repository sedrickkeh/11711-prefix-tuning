# %%
# !nvidia-smi
# Out:
# Sat Nov  6 09:31:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/sedrickkeh/PrefixTuning.git
# !git clone https://github.com/sedrickkeh/dart.git
# !git clone https://github.com/tuetschek/e2e-metrics.git
# Out:
# Cloning into 'PrefixTuning'...
# remote: Enumerating objects: 535, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 535 (delta 39), reused 9 (delta 9), pack-reused 462
# Receiving objects: 100% (535/535), 20.09 MiB | 18.80 MiB/s, done.
# Resolving deltas: 100% (200/200), done.
# Cloning into 'dart'...
# remote: Enumerating objects: 11674, done.
# remote: Counting objects: 100% (11437/11437), done.
# remote: Compressing objects: 100% (8967/8967), done.
# remote: Total 11674 (delta 2529), reused 11336 (delta 2446), pack-reused 237
# Receiving objects: 100% (11674/11674), 271.07 MiB | 27.91 MiB/s, done.
# Resolving deltas: 100% (2565/2565), done.
# Checking out files: 100% (1525/1525), done.
# Cloning into 'e2e-metrics'...
# remote: Enumerating objects: 909, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# ...

# %%
# !mkdir dart-eval2
# %cd dart-eval2/
# !gdown https://drive.google.com/uc?id=1G6CDOtb-f9iTfTk_ArBam5zrHa7zRPST
# !tar xzvf dart-eval2.tar.gz
# !rm dart-eval2.tar.gz
# %cd ..
# Out:
# /content/dart-eval2
# Downloading...
# From: https://drive.google.com/uc?id=1G6CDOtb-f9iTfTk_ArBam5zrHa7zRPST
# To: /content/dart-eval2/dart-eval2.tar.gz
# 100% 241M/241M [00:02<00:00, 111MB/s]
# ./
# ./tercom-0.7.25/
# ./tercom-0.7.25/README.txt
# ./tercom-0.7.25/LICENSE.txt
# ./tercom-0.7.25/tercom.7.25.jar
# ./tercom-0.7.25/src/
# ./tercom-0.7.25/src/TERtest.class
# ./tercom-0.7.25/src/TERsgml$TAGNAME.class
# ./tercom-0.7.25/src/TERcalc.java
# ./tercom-0.7.25/src/TERcost.class
# ./tercom-0.7.25/src/TERalignment.class
# ./tercom-0.7.25/src/TERcost.java
# ./tercom-0.7.25/src/TERtest.java
# ./tercom-0.7.25/src/TERshift.java
# ./tercom-0.7.25/src/TERsgml.java
# ./tercom-0.7.25/src/TERintpair.class
# ./tercom-0.7.25/src/TERtag.java
# ./tercom-0.7.25/src/TERcalc.class
# ./tercom-0.7.25/src/mainClass.txt
# ./tercom-0.7.25/src/TERpara.java
# ./tercom-0.7.25/src/TERsgml$2.class
# ./tercom-0.7.25/src/TERalignment.java
# ./tercom-0.7.25/src/TERtag.class
# ./tercom-0.7.25/src/TERsgml$1.class
# ...

# %%
cd PrefixTuning/transformers
# Out:
# /content/PrefixTuning/transformers

# %%
# !pip install -e .
# !pip install git+https://github.com/PyTorchLightning/pytorch-lightning
# !pip install gitpython
# !pip install rouge_score
# !pip install sacrebleu
# !pip install unidecode
# Out:
# Obtaining file:///content/PrefixTuning/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 3.0 MB 9.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 30.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 32.5 MB/s
# ...
#   Running setup.py develop for transformers
# ...
#   Cloning https://github.com/PyTorchLightning/pytorch-lightning to /tmp/pip-req-build-1o8espev
#   Running command git clone -q https://github.com/PyTorchLightning/pytorch-lightning /tmp/pip-req-build-1o8espev
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 596 kB 13.6 MB/s
# ...
#      |████████████████████████████████| 329 kB 54.5 MB/s
# ...
#      |████████████████████████████████| 829 kB 40.7 MB/s
# ...

# %%
cd ../gpt2
# Out:
# /content/PrefixTuning/gpt2

# %%
import time 
start = time.time()

# !python train_e2e.py --mode triples --preseqlen 20 --seed 9 --bsz 5 --epoch 5 --learning_rate 0.00008

end = time.time()
print(f"Time taken: {end-start} seconds")
# Out:
# Streaming output truncated to the last 5000 lines.
# ('eattype', 'food', 'pricerange', 'customer rating', 'area', 'familyfriendly', 'near')
# cat
# True True
# control code is  None
# beam
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
#  The Vaults : eattype : pub | The Vaults : food : Italian | The Vaults : pricerange : moderate | The Vaults : customer rating : 1 out of 5 | The Vaults : area : riverside | The Vaults : familyfriendly : yes | The Vaults : near : Rainbow Vegetarian Café <|endoftext|> The Vaults is a kid friendly Italian pub near Rainbow Vegetarian Café in riverside with a moderate price range and a customer rating of 1 out of 5. <|endoftext|>
#
# ...

# %% [markdown]
# ## Eval files

# %%
# %cd ../PrefixTuning/gpt2
# Out:
# /content/PrefixTuning/gpt2

# %%
# !python ../../dart-eval2/tolower.py triples_models/triplesprefixtune_y_20_act_cat_b=5-e=1_d=0.0_u=no_lr=8e-05_w=0.0_s=9_r=n_m=512_o=1_o=1_test_beam
# Out:
# triples_models/triplesprefixtune_y_20_act_cat_b=5-e=5_d=0.0_u=no_lr=8e-05_w=0.0_s=9_r=n_m=512_o=1_o=1_test_beam
# ['Zizzi is a pub in the riverside area.\n', 'Zizzi is a pub near Burger King with an average customer rating.\n', 'Zizzi is a highly rated pub near Burger King.\n', 'Zizzi is a pub near Burger King.\n', 'Zizzi is a pub located near The Sorrento.\n']
# ['Zizzi is a pub in the riverside area .', 'Zizzi is a pub near Burger King with an average customer rating .', 'Zizzi is a highly rated pub near Burger King .', 'Zizzi is a pub near Burger King .', 'Zizzi is a pub located near The Sorrento .']

# %%
# %cd ../../dart-eval2
# !cp ../PrefixTuning/gpt2/triples_models/triplesprefixtune_y_20_act_cat_b=5-e=5_d=0.0_u=no_lr=8e-05_w=0.0_s=9_r=n_m=512_o=1_o=1_test_beam.lt2 ./
# !cp ../dart/evaluation/run_eval_on_dart.sh ./
# Out:
# /content/dart-eval2

# %%
# BLEUrt
# %cd ..
# !git clone https://github.com/google-research/bleurt.git
# %cd bleurt
# !pip install .
# %cd ../dart-eval2

# Bertscore
# !git clone https://github.com/sedrickkeh/bert_score.git
# %cd bert_score
# !pip install .
# %cd ..

# Moverscore
# !pip install moverscore
# Out:
# /content
# Cloning into 'bleurt'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 116 (delta 32), reused 55 (delta 20), pack-reused 40
# Receiving objects: 100% (116/116), 31.27 MiB | 25.68 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/bleurt
# Processing /content/bleurt
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#      |████████████████████████████████| 352 kB 11.5 MB/s
# ...

# %%
# !pwd
# Out:
# /content/dart-eval2

# %%
cp triplesprefixtune_y_20_act_cat_b=5-e=5_d=0.0_u=no_lr=8e-05_w=0.0_s=9_r=n_m=512_o=1_o=1_test_beam.lt2 ./meteor-1.5/

# %%
# !bash run_eval_on_dart.sh triplesprefixtune_y_20_act_cat_b=5-e=5_d=0.0_u=no_lr=8e-05_w=0.0_s=9_r=n_m=512_o=1_o=1_test_beam.lt2
# Out:
# triplesprefixtune_y_20_act_cat_b=5-e=5_d=0.0_u=no_lr=8e-05_w=0.0_s=9_r=n_m=512_o=1_o=1_test_beam.lt2
#
# /root/temp_eval/
# /root/temp_eval/relexicalised_predictions-ter.txt
# Downloading: 100% 442/442 [00:00<00:00, 496kB/s]
# Downloading: 100% 232k/232k [00:00<00:00, 708kB/s]
# Downloading: 100% 268M/268M [00:07<00:00, 38.1MB/s]
# /content/PrefixTuning/transformers/src/transformers/tokenization_utils_base.py:1324: FutureWarning: The `max_len` attribute has been deprecated and will be removed in a future version, use `model_max_length` instead.
#   FutureWarning,
# /content/PrefixTuning/transformers/src/transformers/tokenization_utils_base.py:1324: FutureWarning: The `max_len` attribute has been deprecated and will be removed in a future version, use `model_max_length` instead.
#   FutureWarning,
# ...
